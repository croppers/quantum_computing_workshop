# %% [markdown]
# # Installing Qiskit
# first, we need to download the package

# %%
# !pip install qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-0.37.0.tar.gz (13 kB)
# Collecting qiskit-terra==0.21.0
#   Downloading qiskit_terra-0.21.0-cp38-cp38-win_amd64.whl (6.3 MB)
# Collecting qiskit-aer==0.10.4
#   Downloading qiskit_aer-0.10.4-cp38-cp38-win_amd64.whl (24.2 MB)
# Collecting qiskit-ibmq-provider==0.19.2
#   Downloading qiskit_ibmq_provider-0.19.2-py3-none-any.whl (240 kB)
# Requirement already satisfied: scipy>=1.0 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-aer==0.10.4->qiskit) (1.6.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-aer==0.10.4->qiskit) (1.20.3)
# Requirement already satisfied: requests>=2.19 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.25.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.26.6)
# Collecting websockets>=10.0
#   Downloading websockets-10.3-cp38-cp38-win_amd64.whl (98 kB)
# Collecting requests-ntlm>=1.1.0
#   Downloading requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.8.2)
# Collecting websocket-client>=1.0.1
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
# Collecting tweedledum<2.0,>=1.1
#   Downloading tweedledum-1.1.1-cp38-cp38-win_amd64.whl (1.1 MB)
# Requirement already satisfied: sympy>=1.3 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-terra==0.21.0->qiskit) (1.8)
# Collecting retworkx>=0.11.0
#   Downloading retworkx-0.11.0-cp38-cp38-win_amd64.whl (1.2 MB)
# Collecting stevedore>=3.0.0
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
# Requirement already satisfied: dill>=0.3 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-terra==0.21.0->qiskit) (0.3.4)
# Requirement already satisfied: ply>=3.10 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-terra==0.21.0->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\cropp\anaconda3\lib\site-packages (from qiskit-terra==0.21.0->qiskit) (5.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\cropp\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.16.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cropp\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cropp\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2021.10.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\cropp\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (4.0.0)
# Collecting ntlm-auth>=1.0.2
#   Downloading ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: cryptography>=1.3 in c:\users\cropp\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\cropp\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\cropp\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (2.20)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\cropp\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra==0.21.0->qiskit) (1.2.1)
# Building wheels for collected packages: qiskit
#   Building wheel for qiskit (setup.py): started
#   Building wheel for qiskit (setup.py): finished with status 'done'
#   Created wheel for qiskit: filename=qiskit-0.37.0-py3-none-any.whl size=12012 sha256=58269aac043f975cb76ebebba0ff8b744160c8cf5140214b54bab6be939592d6
#   Stored in directory: c:\users\cropp\appdata\local\pip\cache\wheels\b5\6a\75\aa79da63981473b77405655d932d66f29c57485d34f9c00d9e
# Successfully built qiskit
# Installing collected packages: pbr, tweedledum, stevedore, retworkx, ntlm-auth, websockets, websocket-client, requests-ntlm, qiskit-terra, qiskit-ibmq-provider, qiskit-aer, qiskit
#   Attempting uninstall: websockets
#     Found existing installation: websockets 9.0.1
#     Uninstalling websockets-9.0.1:
#       Successfully uninstalled websockets-9.0.1
# Successfully installed ntlm-auth-1.5.0 pbr-5.9.0 qiskit-0.37.0 qiskit-aer-0.10.4 qiskit-ibmq-provider-0.19.2 qiskit-terra-0.21.0 requests-ntlm-1.1.0 retworkx-0.11.0 stevedore-3.5.0 tweedledum-1.1.1 websocket-client-1.3.3 websockets-10.3
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)

# %% [markdown]
# it should now show up in the list of installed packages

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.12.0
# aiohttp                            3.7.4.post0
# alabaster                          0.7.12
# alembic                            1.6.4
# anaconda-client                    1.8.0
# anaconda-navigator                 2.1.2
# anaconda-project                   0.10.1
# antlr4-python3-runtime             4.7.2
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrayfire                          3.8.0
# asn1crypto                         1.4.0
# astroid                            2.6.4
# astropy                            4.2.1
# astunparse                         1.6.3
# async-generator                    1.10
# async-timeout                      3.0.1
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.3
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# basemap                            1.2.1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           2.1.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.1
# bokeh                              2.3.3
# bootstrapped                       0.0.2
# Boruta                             0.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# branca                             0.4.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         4.2.2
# Cartopy                            0.18.0
# cdsapi                             0.3.0
# certifi                            2021.10.8
# cf-units                           3.0.1
# cffi                               1.14.6
# cftime                             1.5.0
# chardet                            4.0.0
# click                              8.0.1
# click-plugins                      1.1.1
# cligj                              0.7.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# cocos                              0.2.2
# colorama                           0.4.4
# comtypes                           1.1.10
# conda                              4.12.0
# conda-build                        3.21.8
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# contexttimer                       0.3.3
# correlation                        1.0.0
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.24
# cytoolz                            0.11.0
# dask                               2021.7.0
# decorator                          5.0.9
# defusedxml                         0.7.1
# descartes                          1.1.0
# diff-match-patch                   20200713
# dill                               0.3.4
# distributed                        2021.7.0
# distro                             1.7.0
# docopt                             0.6.2
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastcache                          1.1.0
# filelock                           3.0.12
# Fiona                              1.8.21
# flake8                             3.8.3
# Flask                              1.1.2
# flatbuffers                        1.12
# folium                             0.12.1.post1
# fsspec                             2021.7.0
# future                             0.18.2
# fuzzywuzzy                         0.18.0
# gast                               0.4.0
# GDAL                               3.4.1
# geopandas                          0.10.2
# gevent                             21.1.2
# glob2                              0.7
# gmpy2                              2.0.8
# google-auth                        1.30.0
# google-auth-oauthlib               0.4.4
# google-pasta                       0.2.0
# greenlet                           1.1.0
# grpcio                             1.34.1
# h5py                               3.3.0
# HeapDict                           1.0.1
# html5lib                           1.1
# hurst                              0.0.5
# idna                               2.10
# imagecodecs                        2021.6.8
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# importlib-resources                5.6.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# iris                               1.0.7
# isort                              5.9.2
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             3.0.1
# joblib                             1.0.1
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.6.1
# jupyterlab-widgets                 1.0.0
# Keras                              2.4.3
# keras-nightly                      2.5.0.dev2021032900
# Keras-Preprocessing                1.1.2
# keyring                            23.0.1
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cropp\anaconda3\lib\site-packages)
# loky                               3.1.0
# lowess                             1.0.3
# lxml                               4.6.3
# Mako                               1.1.4
# mapclassify                        2.4.3
# Markdown                           3.3.4
# MarkupSafe                         2.0.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# menuinst                           1.4.16
# MetPy                              1.2.0
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.8.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multidict                          5.1.0
# multipledispatch                   0.6.0
# multiprocess                       0.70.12.2
# munch                              2.5.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nbgrader                           0.6.1
# nest-asyncio                       1.5.1
# netCDF4                            1.5.7
# networkx                           2.6.1
# nltk                               3.6.2
# nolds                              0.5.2
# nose                               1.3.7
# notebook                           6.4.0
# ntlm-auth                          1.5.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.3
# numpydoc                           1.1.0
# oauthlib                           3.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# opt-einsum                         3.3.0
# packaging                          21.0
# palettable                         3.3.0
# pandas                             1.3.0
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathos                             0.2.8
# pathspec                           0.7.0
# pathtools                          0.1.2
# patsy                              0.5.1
# pbr                                5.9.0
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.3.1
# Pint                               0.18
# pip                                21.1.3
# pkginfo                            1.7.1
# pluggy                             0.13.1
# ply                                3.11
# pooch                              1.6.0
# pox                                0.3.0
# ppft                               1.6.6.4
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.17
# protobuf                           3.17.0
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# Pydap                              3.2.2
# pydocstyle                         6.1.1
# pyerfa                             2.0.0
# pyflakes                           2.2.0
# Pygments                           2.9.0
# pyhdf                              0.10.2
# PyJWT                              2.1.0
# pylint                             2.9.3
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyproj                             2.6.1.post1
# pyreadline                         2.1
# pyrsistent                         0.17.3
# pysal                              2.0.0
# pyshp                              2.1.3
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-editor                      1.0.4
# python-http-client                 3.3.7
# python-igraph                      0.8.3
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# python-Levenshtein                 0.12.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# qiskit                             0.37.0
# qiskit-aer                         0.10.4
# qiskit-ibmq-provider               0.19.2
# qiskit-terra                       0.21.0
# QtAwesome                          1.0.2
# qtconsole                          5.1.0
# QtPy                               1.9.0
# recombinator                       0.0.6.1
# regex                              2021.7.6
# regionmask                         0.4.0
# requests                           2.25.1
# requests-ntlm                      1.1.0
# requests-oauthlib                  1.3.0
# retworkx                           0.11.0
# rope                               0.19.0
# rsa                                4.7.2
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# Rx                                 3.2.0
# scikit-build                       0.14.1
# scikit-image                       0.18.1
# scikit-learn                       0.24.2
# scipy                              1.6.2
# scitools-iris                      3.1.0
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# sendgrid                           6.9.7
# setuptools                         52.0.0.post20210125
# Shapely                            1.7.1
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.16.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.0.2
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.21
# starkbank-ecdsa                    2.0.3
# statsmodels                        0.12.2
# stevedore                          3.5.0
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# tensorboard                        2.5.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.0
# tensorflow                         2.5.0
# tensorflow-estimator               2.5.0
# termcolor                          1.1.0
# terminado                          0.9.4
# testpath                           0.5.0
# textdistance                       4.2.1
# texttable                          1.6.3
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.61.2
# traitlets                          5.0.5
# tweedledum                         1.1.1
# twitch-python                      0.0.19
# twitchAPI                          2.3.2
# typed-ast                          1.4.3
# typing-extensions                  3.10.0.0
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.6
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# WebOb                              1.8.6
# websocket-client                   1.3.3
# websockets                         10.3
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xarray                             0.18.2
# xlrd                               2.0.1
# XlsxWriter                         1.4.4
# xlwings                            0.24.3
# xlwt                               1.3.0
# xmltodict                          0.12.0
# xxhash                             0.0.0
# xyzservices                        2022.3.0
# yapf                               0.31.0
# yarl                               1.6.3
# zict                               2.0.0
# zipp                               3.5.0
# zope.event                         4.5.0
# zope.interface                     5.4.0

# %% [markdown]
# and we should be able to successfully import qiskit into our code!

# %%
import qiskit
